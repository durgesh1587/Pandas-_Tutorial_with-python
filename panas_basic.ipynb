# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("services.csv")

# %%
#this fuction only frist col colected 5 data 
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
#this function using three row and col frist line .....
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
#last 5  record check rule using .
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
#this rule using find last 3 data find ......
df.tail(3)
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...        None
# ...

# %%
type (df)
# Out:
# pandas.core.frame.DataFrame

# %%
# this rules using data colums using this code .
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#this rules using list in show my call data 
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
#this function using data any sinle data aceese  ......
df['status']
# Out:
# 0       active
# 1       active
# 2       active
# 3       active
# 4       active
# 5       active
# 6       active
# 7       active
# 8       active
# 9       active
# 10      active
# 11      active
# 12      active
# 13      active
# 14      active
# 15      active
# 16      active
# 17      active
# 18      active
# 19     defunct
# 20    inactive
# 21      active
# 22      active
# Name: status, dtype: object

# %%
##using [] duble brackit using he is show me dataframe not (data series)
type(df[['status']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['status']]
# Out:
#       status
# 0     active
# 1     active
# 2     active
# 3     active
# 4     active
# 5     active
# 6     active
# 7     active
# 8     active
# 9     active
# 10    active
# 11    active
# 12    active
# 13    active
# 14    active
# 15    active
# 16    active
# 17    active
# 18    active
# 19   defunct
# 20  inactive
# 21    active
# 22    active

# %%
type(df['status'])
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
#this function ueing multipule data with accese 
df[['email' ,'name']]
# Out:
#                     email                                  name
# 0                     NaN       Fair Oaks Adult Activity Center
# 1                     NaN      Second Career Employment Program
# 2                     NaN                Senior Peer Counseling
# 3                     NaN              Family Visitation Center
# 4                     NaN     Economic Self-Sufficiency Program
# 5                     NaN  Little House Recreational Activities
# 6                     NaN      Rosener House Adult Day Services
# 7                     NaN        Meals on Wheels - South County
# 8                     NaN                      Fair Oaks Branch
# 9                     NaN                          Main Library
# 10                    NaN                       Schaberg Branch
# 11                    NaN                          Project Read
# 12                    NaN                 Redwood Shores Branch
# 13                    NaN                    Redwood City Corps
# ...

# %%
# this function using pandas know this type data ...str, int ,float ,ect .
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
fd=pd.read_excel("LUSID Excel - Setting up your market data.xlsx")

# %%
fd.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
fd.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
fd[['Unnamed: 0','Unnamed: 2','Unnamed: 8']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fd[['Unnamed: 0','Unnamed: 2','Unnamed: 8']]
#
# NameError: name 'fd' is not defined

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 42.8 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml
import pandas as pd
url_data=pd.read_html("https://www.basketball-reference.com/players/a/abdulka01.html")

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 7

# %%
df=url_data[0]

# %%
df
# Out:
#         Season   Age   Tm   Lg  Pos       G     GS    MP    FG   FGA  ...  \
# 0      1969-70  22.0  MIL  NBA    C    82.0    NaN  43.1  11.4  22.1  ...
# 1      1970-71  23.0  MIL  NBA    C    82.0    NaN  40.1  13.0  22.5  ...
# 2      1971-72  24.0  MIL  NBA    C    81.0    NaN  44.2  14.3  24.9  ...
# 3      1972-73  25.0  MIL  NBA    C    76.0    NaN  42.8  12.9  23.3  ...
# 4      1973-74  26.0  MIL  NBA    C    81.0    NaN  43.8  11.7  21.7  ...
# 5      1974-75  27.0  MIL  NBA    C    65.0    NaN  42.3  12.5  24.4  ...
# 6      1975-76  28.0  LAL  NBA    C    82.0    NaN  41.2  11.1  21.1  ...
# 7      1976-77  29.0  LAL  NBA    C    82.0    NaN  36.8  10.8  18.7  ...
# 8      1977-78  30.0  LAL  NBA    C    62.0    NaN  36.5  10.7  19.4  ...
# 9      1978-79  31.0  LAL  NBA    C    80.0    NaN  39.5   9.7  16.8  ...
# 10     1979-80  32.0  LAL  NBA    C    82.0    NaN  38.3  10.2  16.9  ...
# 11     1980-81  33.0  LAL  NBA    C    80.0    NaN  37.2  10.5  18.2  ...
# ...

# %%
df.head()
# Out:
#     Season   Age   Tm   Lg Pos     G  GS    MP    FG   FGA  ...    FT%  ORB  \
# 0  1969-70  22.0  MIL  NBA   C  82.0 NaN  43.1  11.4  22.1  ...  0.653  NaN
# 1  1970-71  23.0  MIL  NBA   C  82.0 NaN  40.1  13.0  22.5  ...  0.690  NaN
# 2  1971-72  24.0  MIL  NBA   C  81.0 NaN  44.2  14.3  24.9  ...  0.689  NaN
# 3  1972-73  25.0  MIL  NBA   C  76.0 NaN  42.8  12.9  23.3  ...  0.713  NaN
# 4  1973-74  26.0  MIL  NBA   C  81.0 NaN  43.8  11.7  21.7  ...  0.702  3.5
#
#     DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0   NaN  14.5  4.1  NaN  NaN  NaN  3.5  28.8
# 1   NaN  16.0  3.3  NaN  NaN  NaN  3.2  31.7
# 2   NaN  16.6  4.6  NaN  NaN  NaN  2.9  34.8
# 3   NaN  16.1  5.0  NaN  NaN  NaN  2.7  30.2
# 4  11.0  14.5  4.8  1.4  3.5  NaN  2.9  27.0
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#         Season   Age   Tm   Lg  Pos       G     GS    MP    FG   FGA  ...  \
# 19     1988-89  41.0  LAL  NBA    C    74.0   74.0  22.9   4.2   8.9  ...
# 20      Career   NaN  NaN  NBA  NaN  1560.0  625.0  36.8  10.2  18.1  ...
# 21         NaN   NaN  NaN  NaN  NaN     NaN    NaN   NaN   NaN   NaN  ...
# 22  14 seasons   NaN  LAL  NBA  NaN  1093.0  625.0  34.3   9.1  16.0  ...
# 23   6 seasons   NaN  MIL  NBA  NaN   467.0    NaN  42.7  12.6  23.1  ...
#
#       FT%  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 19  0.739  1.4   3.1   4.5  1.0  0.5  1.1  1.3  2.6  10.1
# 20  0.721  2.4   7.6  11.2  3.6  0.9  2.6  2.7  3.0  24.6
# 21    NaN  NaN   NaN   NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 22  0.737  2.3   7.1   9.4  3.3  0.9  2.5  2.7  2.9  22.1
# 23  0.695  3.3  11.0  15.3  4.3  1.2  3.4  NaN  3.1  30.4
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Season', 'Age', 'Tm', 'Lg', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df[['Tm', 'Lg', 'Pos', 'G', 'GS']]
# Out:
#      Tm   Lg  Pos       G     GS
# 0   MIL  NBA    C    82.0    NaN
# 1   MIL  NBA    C    82.0    NaN
# 2   MIL  NBA    C    81.0    NaN
# 3   MIL  NBA    C    76.0    NaN
# 4   MIL  NBA    C    81.0    NaN
# 5   MIL  NBA    C    65.0    NaN
# 6   LAL  NBA    C    82.0    NaN
# 7   LAL  NBA    C    82.0    NaN
# 8   LAL  NBA    C    62.0    NaN
# 9   LAL  NBA    C    80.0    NaN
# 10  LAL  NBA    C    82.0    NaN
# 11  LAL  NBA    C    80.0    NaN
# 12  LAL  NBA    C    76.0   76.0
# 13  LAL  NBA    C    79.0   79.0
# 14  LAL  NBA    C    80.0   80.0
# 15  LAL  NBA    C    79.0   79.0
# 16  LAL  NBA    C    79.0   79.0
# 17  LAL  NBA    C    78.0   78.0
# 18  LAL  NBA    C    80.0   80.0
# 19  LAL  NBA    C    74.0   74.0
# 20  NaN  NBA  NaN  1560.0  625.0
# 21  NaN  NaN  NaN     NaN    NaN
# 22  LAL  NBA  NaN  1093.0  625.0
# 23  MIL  NBA  NaN   467.0    NaN

# %%
#data save any fromet function (any control data not accese and remove and col or row using shift plus tab and read rules )......save data rules = df.to_csv("pylar_data.csv").
df.to_csv("pylar_data.csv",index=False)
